# %% [markdown]
# <a href="https://colab.research.google.com/github/HariomKharwar5/SD_HAriom__121/blob/main/Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
l = [1,2,3,4]

# %%
ar = np.array(l)

# %%
ar
# Out:
# array([1, 2, 3, 4])

# %%
type(l)
# Out:
# list

# %%
type(ar)
# Out:
# numpy.ndarray

# %%
a=[2,3,4]
